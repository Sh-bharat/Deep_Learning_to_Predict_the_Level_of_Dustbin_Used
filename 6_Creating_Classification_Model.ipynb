# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.8/874.8 kB 18.8 MB/s eta 0:00:00
# ...

# %%
## Importing Libraries

import os
import shutil
import zipfile
import cv2
from ultralytics import YOLO
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
shutil.copyfile("/content/drive/MyDrive/Waste_segmentation/Dataset_for_Classification.zip", "/content/Dataset.zip")
# Out:
# '/content/Dataset.zip'

# %%
zip_file_path = '/content/Dataset.zip'
extract_path = '/content'
if not os.path.exists(extract_path):
    os.makedirs(extract_path)
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
model=YOLO('yolov8n-cls.pt')
# Out:
# ...
# 100%|██████████| 5.31M/5.31M [00:00<00:00, 115MB/s]

# %%
# shutil.copyfile('/content/drive/MyDrive/Waste_segmentation/Data_for_Classification.yaml', '/content/args.yaml')
# Out:
# '/content/Waste_Segmentation.yaml'

# %%
model.train(data='/content/Dataset',epochs=150)
# Out:
# Ultralytics YOLOv8.2.102 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
shutil.copytree('/content/runs','/content/drive/MyDrive/Waste_segmentation/Dustbin_Angle_Classification')
# Out:
# '/content/drive/MyDrive/Waste_segmentation/Dustbin_Angle_Classification'
